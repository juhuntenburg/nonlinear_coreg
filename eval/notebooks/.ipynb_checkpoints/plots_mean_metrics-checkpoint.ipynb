# %% [markdown]
# ## Comparing similarity metrics

# %% [markdown]
# importing libraries

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy as sp
import os

# %% [markdown]
# setting variables

# %%
subjects=[]
f = open('/scr/jessica2/Schaare/LEMON/done_freesurfer.txt','r')
for line in f:
    subjects.append(line.strip())

# %%
len(subjects)
# Out:
# 73

# %%
metrics = ['mi','nmi','cc','cr','crl1']
methods = ['linear', 'nonlinear', 'fmap', 'topup']

# %%
metric_path='/scr/kansas1/huntenburg/eval/%s/similarity/metrics_mni_brain.txt' 
#metric_path='/scr/kansas1/huntenburg/eval/%s/similarity/metrics_mni_ofc.txt'
save_path='/scr/kansas1/huntenburg/eval/group/similarity/mni_brain/' 
#save_path='/scr/kansas1/huntenburg/eval/group/similarity/mni_ofc'

# %% [markdown]
# reading metrics and difference values into arrays, doing stats, saving to files

# %%
for metric in metrics:
    if metric=='mi': 
        metric_no=0
    if metric=='nmi': 
        metric_no=1
    if metric=='cc': 
        metric_no=2
    if metric=='cr': 
        metric_no=3
    if metric=='crl1': 
        metric_no=4
    
    for method in methods:
        if method=='linear':
            method_no=0
        if method=='nonlinear':
            method_no=1
        if method=='fmap':
            method_no=2
        if method=='topup':
            method_no=3
            
        # initiate empty arrays and min/max values
        abs_array=np.array([])
        diff_array=np.array([])
        abs_min=[1, 'none']
        abs_max=[0,'none']
        diff_min=[1, 'none']
        diff_max=[-1,'none']
        
        # loop over subjects, read in metrics file
        for subject in range(len(subjects)):
            path = metric_path %(subjects[subject])
            metrics_array=np.loadtxt(path, dtype='float', delimiter=' ')
            
            # define abs and diff values
            abs_val=metrics_array[metric_no, method_no]
            diff_val=metrics_array[metric_no,method_no]-metrics_array[metric_no, 0]
            
            # compare to min/max values and update if applicable
            if abs_val < abs_min[0]:
                abs_min=[abs_val,subjects[subject]]
            if abs_val > abs_max[0]:
                abs_max=[abs_val, subjects[subject]]
                
            if diff_val < diff_min[0]:
                diff_min=[diff_val, subjects[subject]]
            if diff_val > diff_max[0]:
                diff_max=[diff_val, subjects[subject]]
                
            # append values to arrays
            abs_array = np.append(abs_array,abs_val)
            diff_array = np.append(diff_array, diff_val)
            
        # save array of all subjects to file
        if not os.path.isdir(save_path):
            os.mkdir(save_path)
        
        if not os.path.isdir(save_path+'arrays/'):
            os.mkdir(save_path+'arrays/')
        np.save(save_path+'arrays/'+method+'_'+metric+'_abs.npy', abs_array)
        np.save(save_path+'arrays/'+method+'_'+metric+'_diff.npy', diff_array)
        
        # one sample t test if improvement differs from zero
        [ttest_t, ttest_p]=sp.stats.ttest_1samp(diff_array, 0)
        
        # save min/max values and ttest to text
        stats_array=np.array([['ttest improvement to linear[t,p] ',str([ttest_t, ttest_p])]])
        stats_array=np.append(stats_array, [['least improved to linear[val,subj] ',str(diff_min)]], axis=0)
        stats_array=np.append(stats_array, [['most improved to linear[val,subj] ',str(diff_max)]], axis=0)
        stats_array=np.append(stats_array, [['min similarity[val,subj] ',str(abs_min)]], axis=0)
        stats_array=np.append(stats_array, [['max similarity[val,subj] ',str(abs_max)]], axis=0)

        if not os.path.isdir(save_path+'stats/'):
            os.mkdir(save_path+'stats/')
        np.savetxt(save_path+'stats/'+method+'_'+metric+'_stats.txt', stats_array, delimiter=' ', fmt='%s')
        
        # print stats for quick check
        print method+' minimum '+metric+' similarity = '+str(abs_min)
        print method+' maximum '+metric+' similarity = '+str(abs_max)
        print method+' least '+metric+' improvement to linear = '+str(diff_min)
        print method+' highest '+metric+' improvement to linear = '+str(diff_max)
        print method+' '+metric+' improvement diff from zero [t,p] = '+str([ttest_t, ttest_p])
        if ttest_p <= 0.01:
            if ttest_t >=0:
                print metric+' '+method+' significant improvement[t,p] = '+str([ttest_t, ttest_p])
            elif ttest_t <=0:
                print metric+' '+method+' significant deterioration[t,p] = '+str([ttest_t, ttest_p])
# Out:
# linear minimum mi similarity = [0.15742300000000001, 'LEMON064']
# linear maximum mi similarity = [0.204566, 'LEMON059']
# linear least mi improvement to linear = [0.0, 'LEMON001']
# linear highest mi improvement to linear = [0.0, 'LEMON001']
# linear mi improvement diff from zero [t,p] = [array(nan), nan]
# nonlinear minimum mi similarity = [0.154807, 'LEMON064']
# nonlinear maximum mi similarity = [0.20102100000000001, 'LEMON059']
# nonlinear least mi improvement to linear = [-0.0089140000000000053, 'LEMON083']
# nonlinear highest mi improvement to linear = [0.0034409999999999996, 'LEMON006']
# nonlinear mi improvement diff from zero [t,p] = [array(-7.396286829119051), 2.0423033167457279e-10]
# mi nonlinear significant deterioration[t,p] = [array(-7.396286829119051), 2.0423033167457279e-10]
# fmap minimum mi similarity = [0.160916, 'LEMON038']
# fmap maximum mi similarity = [0.199629, 'LEMON085']
# fmap least mi improvement to linear = [-0.0057049999999999879, 'LEMON059']
# fmap highest mi improvement to linear = [0.012706999999999996, 'LEMON017']
# fmap mi improvement diff from zero [t,p] = [array(7.179367066547064), 5.1548242751983152e-10]
# mi fmap significant improvement[t,p] = [array(7.179367066547064), 5.1548242751983152e-10]
# topup minimum mi similarity = [0.16025200000000001, 'LEMON064']
# topup maximum mi similarity = [0.20307500000000001, 'LEMON076']
# topup least mi improvement to linear = [-0.0063439999999999885, 'LEMON012']
# topup highest mi improvement to linear = [0.014061000000000018, 'LEMON017']
# topup mi improvement diff from zero [t,p] = [array(8.10069588640443), 9.9461005918470669e-12]
# mi topup significant improvement[t,p] = [array(8.10069588640443), 9.9461005918470669e-12]
# linear minimum nmi similarity = [0.032749, 'LEMON038']
# linear maximum nmi similarity = [0.041891999999999999, 'LEMON059']
# linear least nmi improvement to linear = [0.0, 'LEMON001']
# linear highest nmi improvement to linear = [0.0, 'LEMON001']
# linear nmi improvement diff from zero [t,p] = [array(nan), nan]
# nonlinear minimum nmi similarity = [0.032807000000000003, 'LEMON083']
# nonlinear maximum nmi similarity = [0.041249000000000001, 'LEMON059']
# nonlinear least nmi improvement to linear = [-0.0014979999999999993, 'LEMON083']
# nonlinear highest nmi improvement to linear = [0.00080500000000000016, 'LEMON006']
# nonlinear nmi improvement diff from zero [t,p] = [array(-6.54601809460013), 7.5108924526398723e-09]
# nmi nonlinear significant deterioration[t,p] = [array(-6.54601809460013), 7.5108924526398723e-09]
# fmap minimum nmi similarity = [0.033280999999999998, 'LEMON038']
# fmap maximum nmi similarity = [0.040910000000000002, 'LEMON085']
# fmap least nmi improvement to linear = [-0.0010849999999999957, 'LEMON059']
# fmap highest nmi improvement to linear = [0.0021050000000000027, 'LEMON017']
# fmap nmi improvement diff from zero [t,p] = [array(7.24645984194449), 3.8725731221555315e-10]
# nmi fmap significant improvement[t,p] = [array(7.24645984194449), 3.8725731221555315e-10]
# topup minimum nmi similarity = [0.033389000000000002, 'LEMON038']
# topup maximum nmi similarity = [0.040996999999999999, 'LEMON062']
# topup least nmi improvement to linear = [-0.0011999999999999997, 'LEMON059']
# topup highest nmi improvement to linear = [0.0024460000000000037, 'LEMON017']
# topup nmi improvement diff from zero [t,p] = [array(8.05624415907569), 1.204053232526355e-11]
# nmi topup significant improvement[t,p] = [array(8.05624415907569), 1.204053232526355e-11]
# linear minimum cc similarity = [3.9999999999999998e-06, 'LEMON029']
# linear maximum cc similarity = [0.048224999999999997, 'LEMON076']
# linear least cc improvement to linear = [0.0, 'LEMON001']
# linear highest cc improvement to linear = [0.0, 'LEMON001']
# linear cc improvement diff from zero [t,p] = [array(nan), nan]
# nonlinear minimum cc similarity = [3.6999999999999998e-05, 'LEMON050']
# nonlinear maximum cc similarity = [0.049882000000000003, 'LEMON031']
# nonlinear least cc improvement to linear = [-0.0011750000000000024, 'LEMON086']
# nonlinear highest cc improvement to linear = [0.0096059999999999982, 'LEMON058']
# nonlinear cc improvement diff from zero [t,p] = [array(14.174703317718794), 1.5950061770499951e-22]
# cc nonlinear significant improvement[t,p] = [array(14.174703317718794), 1.5950061770499951e-22]
# fmap minimum cc similarity = [2.5000000000000001e-05, 'LEMON029']
# fmap maximum cc similarity = [0.035015999999999999, 'LEMON076']
# fmap least cc improvement to linear = [-0.013208999999999999, 'LEMON076']
# fmap highest cc improvement to linear = [0.0031879999999999999, 'LEMON013']
# fmap cc improvement diff from zero [t,p] = [array(-8.056951956815954), 1.2003952971376851e-11]
# cc fmap significant deterioration[t,p] = [array(-8.056951956815954), 1.2003952971376851e-11]
# topup minimum cc similarity = [0.0, 'LEMON029']
# topup maximum cc similarity = [0.037354999999999999, 'LEMON076']
# topup least cc improvement to linear = [-0.011051000000000002, 'LEMON068']
# topup highest cc improvement to linear = [0.004886999999999999, 'LEMON013']
# topup cc improvement diff from zero [t,p] = [array(-5.528961672868559), 4.8872894064495887e-07]
# cc topup significant deterioration[t,p] = [array(-5.528961672868559), 4.8872894064495887e-07]
# linear minimum cr similarity = [0.0095259999999999997, 'LEMON042']
# linear maximum cr similarity = [0.081078999999999998, 'LEMON010']
# linear least cr improvement to linear = [0.0, 'LEMON001']
# linear highest cr improvement to linear = [0.0, 'LEMON001']
# linear cr improvement diff from zero [t,p] = [array(nan), nan]
# nonlinear minimum cr similarity = [0.010449, 'LEMON050']
# nonlinear maximum cr similarity = [0.097003000000000006, 'LEMON010']
# nonlinear least cr improvement to linear = [-0.0019300000000000012, 'LEMON084']
# nonlinear highest cr improvement to linear = [0.025645999999999995, 'LEMON058']
# nonlinear cr improvement diff from zero [t,p] = [array(21.77114960608852), 2.1237812333554807e-33]
# cr nonlinear significant improvement[t,p] = [array(21.77114960608852), 2.1237812333554807e-33]
# fmap minimum cr similarity = [0.010869999999999999, 'LEMON050']
# fmap maximum cr similarity = [0.077316999999999997, 'LEMON010']
# fmap least cr improvement to linear = [-0.013643999999999996, 'LEMON068']
# fmap highest cr improvement to linear = [0.0080360000000000015, 'LEMON013']
# fmap cr improvement diff from zero [t,p] = [array(-2.6761384834723545), 0.0092151379686545506]
# cr fmap significant deterioration[t,p] = [array(-2.6761384834723545), 0.0092151379686545506]
# topup minimum cr similarity = [0.010553, 'LEMON050']
# topup maximum cr similarity = [0.081299999999999997, 'LEMON010']
# topup least cr improvement to linear = [-0.011980999999999999, 'LEMON068']
# topup highest cr improvement to linear = [0.010034000000000001, 'LEMON013']
# topup cr improvement diff from zero [t,p] = [array(-0.5224335339894242), 0.60297232640457421]
# linear minimum crl1 similarity = [0.0089680000000000003, 'LEMON055']
# linear maximum crl1 similarity = [0.033508000000000003, 'LEMON010']
# linear least crl1 improvement to linear = [0.0, 'LEMON001']
# linear highest crl1 improvement to linear = [0.0, 'LEMON001']
# linear crl1 improvement diff from zero [t,p] = [array(nan), nan]
# nonlinear minimum crl1 similarity = [0.012628, 'LEMON050']
# nonlinear maximum crl1 similarity = [0.040841000000000002, 'LEMON010']
# nonlinear least crl1 improvement to linear = [0.00064699999999999827, 'LEMON084']
# nonlinear highest crl1 improvement to linear = [0.011421000000000001, 'LEMON031']
# nonlinear crl1 improvement diff from zero [t,p] = [array(26.728578537314537), 4.0972684370441815e-39]
# crl1 nonlinear significant improvement[t,p] = [array(26.728578537314537), 4.0972684370441815e-39]
# fmap minimum crl1 similarity = [0.0078300000000000002, 'LEMON055']
# fmap maximum crl1 similarity = [0.031001999999999998, 'LEMON010']
# fmap least crl1 improvement to linear = [-0.0077649999999999976, 'LEMON031']
# fmap highest crl1 improvement to linear = [0.0026629999999999987, 'LEMON029']
# fmap crl1 improvement diff from zero [t,p] = [array(-7.228662117244178), 4.1779588636441836e-10]
# crl1 fmap significant deterioration[t,p] = [array(-7.228662117244178), 4.1779588636441836e-10]
# topup minimum crl1 similarity = [0.007424, 'LEMON055']
# topup maximum crl1 similarity = [0.031931000000000001, 'LEMON010']
# topup least crl1 improvement to linear = [-0.0071130000000000013, 'LEMON068']
# topup highest crl1 improvement to linear = [0.0018110000000000001, 'LEMON062']
# topup crl1 improvement diff from zero [t,p] = [array(-7.015474072822312), 1.0350965002418339e-09]
# crl1 topup significant deterioration[t,p] = [array(-7.015474072822312), 1.0350965002418339e-09]

# %% [markdown]
# ## Plotting distributions

# %%
for metric in metrics:
    lin_abs=np.load(save_path+'arrays/linear_'+metric+'_abs.npy')
    nonlin_abs=np.load(save_path+'arrays/nonlinear_'+metric+'_abs.npy')
    fmap_abs=np.load(save_path+'arrays/fmap_'+metric+'_abs.npy')
    topup_abs=np.load(save_path+'arrays/topup_'+metric+'_abs.npy')
    
    sns.set_context(context='talk')
    fig = plt.figure
    fig = plt.figure()
    ax = fig.add_subplot(111)
    sns.violinplot([lin_abs,nonlin_abs,fmap_abs,topup_abs], names=["linear", "nonlinear", "fieldmap","topup"],color='RdBu', 
                   #join_rm=True
                   #inner='points'
                   )
    sns.axlabel('',metric)
    if not os.path.isdir(save_path+'plots/'):
            os.mkdir(save_path+'plots/')
    plt.savefig(save_path+'plots/'+metric+'_violins.svg')
