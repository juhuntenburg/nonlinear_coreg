# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy
import pandas as pd

# %%
nonlin_nmi_diff=np.load('/home/julia/Downloads/nonlin_nmi_diff_array.npy')
fmap_nmi_diff=np.load('/home/julia/Downloads/fmap_nmi_diff_array.npy')
topup_nmi_diff=np.load('/home/julia/Downloads/topup_nmi_diff_array.npy')

nonlin_cr_diff=np.load('/home/julia/Downloads/nonlin_cr_diff_array.npy')
fmap_cr_diff=np.load('/home/julia/Downloads/fmap_cr_diff_array.npy')
topup_cr_diff=np.load('/home/julia/Downloads/topup_cr_diff_array.npy')

lin_nmi=np.load('/home/julia/Downloads/lin_nmi_array.npy')
nonlin_nmi=np.load('/home/julia/Downloads/nonlin_nmi_array.npy')
fmap_nmi=np.load('/home/julia/Downloads/fmap_nmi_array.npy')
topup_nmi=np.load('/home/julia/Downloads/topup_nmi_array.npy')

lin_cr=np.load('/home/julia/Downloads/lin_cr_array.npy')
nonlin_cr=np.load('/home/julia/Downloads/nonlin_cr_array.npy')
fmap_cr=np.load('/home/julia/Downloads/fmap_cr_array.npy')
topup_cr=np.load('/home/julia/Downloads/topup_cr_array.npy')

lin_nmi_ofc=np.load('/home/julia/Downloads/ofc_lin_nmi_array.npy')
nonlin_nmi_ofc=np.load('/home/julia/Downloads/ofc_nonlin_nmi_array.npy')
fmap_nmi_ofc=np.load('/home/julia/Downloads/ofc_fmap_nmi_array.npy')
topup_nmi_ofc=np.load('/home/julia/Downloads/ofc_topup_nmi_array.npy')

lin_cr_ofc=np.load('/home/julia/Downloads/ofc_lin_cr_array.npy')
nonlin_cr_ofc=np.load('/home/julia/Downloads/ofc_nonlin_cr_array.npy')
fmap_cr_ofc=np.load('/home/julia/Downloads/ofc_fmap_cr_array.npy')
topup_cr_ofc=np.load('/home/julia/Downloads/ofc_topup_cr_array.npy')

# %%
nmi_fig=plt.figure(1)
sns.set_context(context='talk')
sns.violinplot([lin_nmi,nonlin_nmi,fmap_nmi,topup_nmi], names=["linear", "nonlinear", "fieldmap","topup"],color='RdBu')
#nmi_plot=sns.axlabel('','NMI')
plt.savefig('/home/julia/Documents/nmi_fig.svg')
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1224: UserWarning: findfont: Font family ['Arial'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1234: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=13.0. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
sns.violinplot([lin_cr,nonlin_cr,fmap_cr, topup_cr], names=["linear", "nonlinear", "fieldmap","topup"],color='RdBu')
#sns.axlabel('','CR')
plt.savefig('/home/julia/Documents/cr_fig.svg')

# %%
sns.set_context(context='talk')
sns.violinplot([lin_nmi_ofc,nonlin_nmi_ofc,fmap_nmi_ofc,topup_nmi_ofc], names=["linear", "nonlinear", "fieldmap","topup"],color='RdBu')
#sns.axlabel('','NMI')
plt.savefig('/home/julia/Documents/ofc_nmi_fig.svg')

# %%
sns.violinplot([lin_cr_ofc,nonlin_cr_ofc,fmap_cr_ofc, topup_cr_ofc], names=["linear", "nonlinear", "fieldmap","topup"],color='RdBu')
#sns.axlabel('','CR')
plt.savefig('/home/julia/Documents/ofc_cr_fig.svg')

# %%
print plt.get_cmap('coolwarm_r')
